# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math


titanic_data=pd.read_csv(r'C:\Users\cruise\desktop\Dataset\Titanic.csv')
titanic_data.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
# 5         0       3                                    Mr. James Moran
# 6         0       1                             Mr. Timothy J McCarthy
# 7         0       3                      Master. Gosta Leonard Palsson
# 8         1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9         1       2                 Mrs. Nicholas (Adele Achem) Nasser
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# ...

# %%
sns.distplot(titanic_data["Age"])
plt.grid(True)

# %%
sns.jointplot(x="Age",y='Fare', data=titanic_data, kind='hex')
sns.axisgrid
# Out:
# <module 'seaborn.axisgrid' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\seaborn\\axisgrid.py'>

# %%
sns.pairplot(titanic_data, hue='Sex',height=3.0)
plt.grid(True)

# %%
sns.rugplot(titanic_data["Age"])
sns.set_style(style='whitegrid')

# %% [markdown]
# # categorica plot

# %%
sns.barplot(x="Sex",y="Age",data=titanic_data)
## average age of male and female

# %%
sns.barplot(x="Sex",y="Age",data=titanic_data, estimator=np.std)
## average age of male and female, by default baplot gives avesns.barplot(x="Sex",y="Age",data=titanic_data)
## average age of male and femaleage

# %%
sns.countplot(x="Sex", data=titanic_data)

# %%
sns.boxplot(x="Sex",y="Age", data=titanic_data)

# %%
sns.boxplot(x="Sex",y="Age", data=titanic_data, hue="Survived")

# %%
sns.violinplot(x="Sex",y="Age", data=titanic_data)

# %%
sns.violinplot(x="Sex",y="Age", data=titanic_data, hue="Survived")

# %%
sns.violinplot(x="Sex",y="Age", data=titanic_data, hue="Survived", split=True)

# %%
sns.stripplot(x="Sex",y="Age", data=titanic_data)

# %%
sns.stripplot(x="Sex",y="Age", data=titanic_data, jitter=True)

# %%
sns.swarmplot(x="Sex",y="Age", data=titanic_data)

# %%
sns.violinplot(x="Sex",y="Age", data=titanic_data)
sns.swarmplot(x="Sex",y="Age", data=titanic_data)

# %%
sns.factorplot(x="Sex",y="Age", data=titanic_data, kind='bar')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.catplot(x="Sex",y="Age", data=titanic_data, kind='bar')

# %%
tc=titanic_data.corr()

# %%
sns.heatmap(tc,annot=True)

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data, hue="Survived", markers=["o","+"])

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data,col="Sex")

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data,col="Sex",row="Survived")

# %%
flights=titanic_data[["Survived","Fare","Name","Sex","Age"]]

# %%
flights
# Out:
#      Survived     Fare                                               Name  \
# 0           0   7.2500                             Mr. Owen Harris Braund
# 1           1  71.2833  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1   7.9250                              Miss. Laina Heikkinen
# 3           1  53.1000        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0   8.0500                            Mr. William Henry Allen
# ..        ...      ...                                                ...
# 882         0  13.0000                               Rev. Juozas Montvila
# 883         1  30.0000                        Miss. Margaret Edith Graham
# 884         0  23.4500                     Miss. Catherine Helen Johnston
# 885         1  30.0000                               Mr. Karl Howell Behr
# 886         0   7.7500                                 Mr. Patrick Dooley
#
#         Sex   Age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# ...

# %%
fp=flights.pivot_table(index="Name",columns="Age",values="Fare")

# %%
sns.heatmap(fp)

# %%
sns.clustermap(fp)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in calculated_linkage(self)
#     625         try:
# --> 626             return self._calculate_linkage_fastcluster()
#     627         except ImportError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in _calculate_linkage_fastcluster(self)
#     606     def _calculate_linkage_fastcluster(self):
# --> 607         import fastcluster
#     608         # Fastcluster has a memory-saving vectorized version, but only
#
# ModuleNotFoundError: No module named 'fastcluster'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-837894e9a9b7> in <module>
# ----> 1 sns.clustermap(fp)
#
# ...

# %% [markdown]
# # regression plot

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data)

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data, hue="Survived", markers=["o","+"])

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data,col="Sex")

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data,row="Survived")

# %%
sns.lmplot(x="Fare", y="Age", data=titanic_data,col="Sex",row="Survived")

# %%
y=sns.PairGrid(titanic_data)
y.map(plt.scatter)

# %%
y=sns.PairGrid(titanic_data)
y.map_diag(sns.distplot)

# %%
y=sns.PairGrid(titanic_data)
y.map_diag(sns.distplot)
y.map_upper(sns.scatterplot)
y.map_lower(sns.kdeplot)
